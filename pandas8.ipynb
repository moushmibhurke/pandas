# %%
import pandas as pd
india_weather = pd.DataFrame({
    'city':['mumbai','delhi','banglore'],
    'temerature':[35,38,33],
    'humidity':[80,60,70]
})
india_weather
# Out:
#        city  temerature  humidity
# 0    mumbai          35        80
# 1     delhi          38        60
# 2  banglore          33        70

# %%
import pandas as pd
us_weather = pd.DataFrame({
    'city':['houston','new york','orlando'],
    'temerature':[33,20,35],
    'humidity':[60,75,70]
})
us_wedfather
# Out:
#        city  temerature  humidity
# 0   houston          33        60
# 1  new york          20        75
# 2   orlando          35        70

# %%
df = pd.concat([india_weather,us_weather])
df
# Out:
#        city  temerature  humidity
# 0    mumbai          35        80
# 1     delhi          38        60
# 2  banglore          33        70
# 0   houston          33        60
# 1  new york          20        75
# 2   orlando          35        70

# %%
df = pd.concat([india_weather,us_weather], ignore_index=True)
df
# Out:
#        city  temerature  humidity
# 0    mumbai          35        80
# 1     delhi          38        60
# 2  banglore          33        70
# 3   houston          33        60
# 4  new york          20        75
# 5   orlando          35        70

# %%
df = pd.concat([india_weather, us_weather], keys=['india','us']) #ignore_index and keys cannot work together 
df
# Out:
#              city  temerature  humidity
# india 0    mumbai          35        80
#       1     delhi          38        60
#       2  banglore          33        70
# us    0   houston          33        60
#       1  new york          20        75
#       2   orlando          35        70

# %%
df.loc['india'] #location
# Out:
#        city  temerature  humidity
# 0    mumbai          35        80
# 1     delhi          38        60
# 2  banglore          33        70

# %%
df.loc['us'] #location
# Out:
#        city  temerature  humidity
# 0   houston          33        60
# 1  new york          20        75
# 2   orlando          35        70

# %%
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({
    'city':['mumbai','delhi','banglore'],
    'windspeed':[8,6,7]
})
windspeed_df
# Out:
#        city  windspeed
# 0    mumbai          8
# 1     delhi          6
# 2  banglore          7

# %%
df = pd.concat([temperature_df,windspeed_df],axis=1) #bydefault axis is 0 which append data as rows 
df
# Out:
#        city  temperature      city  windspeed
# 0    mumbai           32    mumbai          8
# 1     delhi           45     delhi          6
# 2  banglore           30  banglore          7

# %%
windspeed_df = pd.DataFrame({
    'city':['delhi',',mumbai'],
    'windspeed':[8,6]
},index=[1,0])
windspeed_df
# Out:
#       city  windspeed
# 1    delhi          8
# 0  ,mumbai          6

# %%
df = pd.concat([temperature_df,windspeed_df],axis=1) 
df
# Out:
#        city  temperature     city  windspeed
# 0    mumbai           32  ,mumbai        6.0
# 1     delhi           45    delhi        8.0
# 2  banglore           30      NaN        NaN

# %%
s = pd.Series(["Humid","Dry","Rain"], name="event") #creating a series 
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
df = pd.concat([temperature_df, s],axis=1)  #joining it to the 
df
# Out:
#        city  temperature  event
# 0    mumbai           32  Humid
# 1     delhi           45    Dry
# 2  banglore           30   Rain
