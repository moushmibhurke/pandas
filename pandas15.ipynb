# %%
import pandas as pd
df = pd.read_csv("C:\pythoncode\data\AAPL.csv")
df.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 247  2021-05-27  126.440002  127.639999  125.080002  125.279999  125.279999
# 248  2021-05-28  125.570000  125.800003  124.550003  124.610001  124.610001
# 249  2021-06-01  125.080002  125.349998  123.940002  124.279999  124.279999
# 250  2021-06-02  124.279999  125.239998  124.050003  125.059998  125.059998
# 251  2021-06-03  124.680000  124.849998  123.129997  123.540001  123.540001
#
#        Volume
# 247  94625600
# 248  71311100
# 249  67637100
# 250  59278900
# 251  76101500

# %%
type(df.Date[0])
# Out:
# str

# %%
df = pd.read_csv("C:\pythoncode\data\AAPL.csv", parse_dates=['Date'], index_col='Date')
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-06-04  81.097504  81.404999  80.195000  80.580002  80.040680   87560400
# 2020-06-05  80.837502  82.937500  80.807503  82.875000  82.320328  137250400
# 2020-06-08  82.562500  83.400002  81.830002  83.364998  82.807037   95654400
# 2020-06-09  83.035004  86.402496  83.002502  85.997498  85.421921  147712400
# 2020-06-10  86.974998  88.692497  86.522499  88.209999  87.619614  166651600

# %%
df.index
# Out:
# DatetimeIndex(['2020-06-04', '2020-06-05', '2020-06-08', '2020-06-09',
#                '2020-06-10', '2020-06-11', '2020-06-12', '2020-06-15',
#                '2020-06-16', '2020-06-17',
#                ...
#                '2021-05-20', '2021-05-21', '2021-05-24', '2021-05-25',
#                '2021-05-26', '2021-05-27', '2021-05-28', '2021-06-01',
#                '2021-06-02', '2021-06-03'],
#               dtype='datetime64[ns]', name='Date', length=252, freq=None)

# %%
df["2020-10"]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-10-01  117.639999  117.720001  115.830002  116.790001  116.217491
# 2020-10-02  112.889999  115.370003  112.220001  113.019997  112.465973
# 2020-10-05  113.910004  116.650002  113.550003  116.500000  115.928909
# 2020-10-06  115.699997  116.120003  112.250000  113.160004  112.605286
# 2020-10-07  114.620003  115.550003  114.129997  115.080002  114.515877
# 2020-10-08  116.250000  116.400002  114.589996  114.970001  114.406410
# 2020-10-09  115.279999  117.000000  114.919998  116.970001  116.396606
# 2020-10-12  120.059998  125.180000  119.279999  124.400002  123.790192
# 2020-10-13  125.269997  125.389999  119.650002  121.099998  120.506355
# 2020-10-14  121.000000  123.029999  119.620003  121.190002  120.595924
# 2020-10-15  118.720001  121.199997  118.150002  120.709999  120.118271
# 2020-10-16  121.279999  121.550003  118.809998  119.019997  118.436554
# ...

# %%
df["2020-10"].Close
# Out:
# Date
# 2020-10-01    116.790001
# 2020-10-02    113.019997
# 2020-10-05    116.500000
# 2020-10-06    113.160004
# 2020-10-07    115.080002
# 2020-10-08    114.970001
# 2020-10-09    116.970001
# 2020-10-12    124.400002
# 2020-10-13    121.099998
# 2020-10-14    121.190002
# 2020-10-15    120.709999
# 2020-10-16    119.019997
# 2020-10-19    115.980003
# 2020-10-20    117.510002
# 2020-10-21    116.870003
# 2020-10-22    115.750000
# 2020-10-23    115.040001
# 2020-10-26    115.050003
# 2020-10-27    116.599998
# 2020-10-28    111.199997
# 2020-10-29    115.320000
# 2020-10-30    108.860001
# Name: Close, dtype: float64

# %%
df["2020-10"].Close.mean()
# Out:
# 116.4131823636364

# %%
df["2020-10-03":"2020-10-08"]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-10-05  113.910004  116.650002  113.550003  116.500000  115.928909
# 2020-10-06  115.699997  116.120003  112.250000  113.160004  112.605286
# 2020-10-07  114.620003  115.550003  114.129997  115.080002  114.515877
# 2020-10-08  116.250000  116.400002  114.589996  114.970001  114.406410
#
#                Volume
# Date
# 2020-10-05  106243800
# 2020-10-06  161498200
# 2020-10-07   96849000
# 2020-10-08   83477200

# %%
df.Close.resample('M').mean() #gives monthly means of close col
# Out:
# Date
# 2020-06-30     87.334604
# 2020-07-31     95.566250
# 2020-08-31    117.299762
# 2020-09-30    115.125237
# 2020-10-31    116.413182
# 2020-11-30    116.825999
# 2020-12-31    127.290455
# 2021-01-31    133.036842
# 2021-02-28    131.531579
# 2021-03-31    121.871304
# 2021-04-30    131.812858
# 2021-05-31    126.784000
# 2021-06-30    124.293333
# Freq: M, Name: Close, dtype: float64

# %%
# %matplotlib inline 
df.Close.resample('M').mean().plot()

# %%
# %matplotlib inline 
df.Close.resample('M').mean().plot(kind="bar")
